# %%
import pandas as pd
import csv
import numpy as np

# %%
pd.read_csv("accidents.csv")
# Out:
#    Year  Fatalities  Injuries  Crashes  Fatal Crashes  \
# 0  2010       32999   2239000  5419000          30296
# 1  2011       32479   2217000  5338000          29867
# 2  2012       33782   2362000  5615000          31006
# 3  2013       32893   2313000  5687000          30202
# 4  2014       32744   2338000  6064000          30056
# 5  2015       35484   2443000  6296000          32538
# 6  2016       37806   3061000  6821000          34748
# 7  2017       37133   2746000  6452000          34247
#
#    Distraction Affected Fatal Crashes  Fatal Crashes involving Cell Phone Use  \
# 0                                3064                                     423
# 1                                3111                                     426
# 2                                3167                                     440
# 3                                2972                                     411
# 4                                3018                                     387
# ...

# %%
test = pd.read_csv("test_nums.csv")

# %%
test
# Out:
#    car   ducky   banana   pizza
# 0    1      34       12       3
# 1   78      64        2       3
# 2    5       9       32       2
# 3   63      54       42      56
# 4   26      43       64      23
# 5   12      98       19      56
# 6   13      45       26       8

# %%
test.Series
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18364\258722267.py in <module>
# ----> 1 test.Series
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Series'
